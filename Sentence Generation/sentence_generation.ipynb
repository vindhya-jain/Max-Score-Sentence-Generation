# %% [markdown]
# Importing reqd modules

# %%
import numpy as np
import heapq
import random
import nltk
from nltk.corpus import words

# %% [markdown]
# ### Loading/generating transition matrix and vocabulary data

# %% [markdown]
# #### For loading data

# %% [markdown]
# Enter input: L, n+2, transition matrix, vocabulary

# %%
L = int(input("L (vocabulary size):"))
n = int(input("n+2 (sentence length): ")) - 2
tmatrix_path = input("transition.txt path: ")
vocab_path = input("vocabulary.txt path: ")
# Out:
# L (vocabulary size): 4
# n+2 (sentence length):  6
# transition.txt path:  sample_transition.txt
# vocabulary.txt path:  sample_vocab.txt

# %%
def load_data(vocab_file, transition_file):
    with open(vocab_file, 'r') as vf:
        vocab = vf.read().splitlines()
    
    transition_matrix = np.loadtxt(transition_file)
    return vocab, transition_matrix

# %%
vocab, tmatrix = load_data(vocab_path, tmatrix_path)
print(vocab)
print(tmatrix)

# bringing row that has P(wi|w0) values at the top to ease indexing
row0 = tmatrix[len(tmatrix) - 2]
tmatrix = np.delete(tmatrix, len(tmatrix) - 2, axis = 0)
tmatrix = np.insert(tmatrix, 0, row0, axis = 0)
print()
print(tmatrix)
# Out:
# ['green', 'grass', 'at', 'airport']
# [[0.6324 0.1576 0.4218 0.8491]
#  [0.0975 0.9706 0.9157 0.934 ]
#  [0.2785 0.9572 0.7922 0.6787]
#  [0.5469 0.4854 0.9595 0.7577]
#  [0.9575 0.8003 0.6557 0.7431]
#  [0.9649 0.1419 0.0357 0.3922]]
#
# [[0.9575 0.8003 0.6557 0.7431]
#  [0.6324 0.1576 0.4218 0.8491]
#  [0.0975 0.9706 0.9157 0.934 ]
#  [0.2785 0.9572 0.7922 0.6787]
#  [0.5469 0.4854 0.9595 0.7577]
#  [0.9649 0.1419 0.0357 0.3922]]

# %% [markdown]
# #### For generating data

# %%
L = 3 #{3,5,10,15}
n = 3 #{3,4,5,6}

# %%
def generate_transition_matrix(L):
    matrix = np.random.rand(L+2, L).round(4)  # Generate random values between 0 and 1, rounded to 4 decimals
    return matrix

tmatrix = generate_transition_matrix(L)
print("Transition Matrix:\n", tmatrix)

# bringing row that has P(wi|w0) values at the top to ease indexing
row0 = tmatrix[len(tmatrix) - 2]
tmatrix = np.delete(tmatrix, len(tmatrix) - 2, axis = 0)
tmatrix = np.insert(tmatrix, 0, row0, axis = 0)
print()
print(tmatrix)

# %%
nltk.download('words')

def generate_meaningful_vocabulary(num_words):
    word_list = words.words()  # List of English words from nltk
    vocabulary = set()
    
    while len(vocabulary) < num_words:
        word = random.choice(word_list)
        vocabulary.add(word)
    
    return sorted(vocabulary)

vocab = generate_meaningful_vocabulary(L)
print("Vocabulary:", vocab)

# %% [markdown]
# #### Normalising Transition Matrix

# %%
for i in range(0, L+1):
    sum = 0
    if(i == 0):
        sum = np.sum(tmatrix[i, :])
        tmatrix[i, :] /= sum
        continue
    sum = np.sum(tmatrix[i, :]) + tmatrix[L+1, i-1]
    tmatrix[i, :] /= sum
    tmatrix[L+1, i-1] = tmatrix[L+1, i-1] / sum
print(tmatrix)
# Out:
# [[0.3033327  0.25353228 0.2077235  0.23541152]
#  [0.20900258 0.0520854  0.13940115 0.28062   ]
#  [0.03186587 0.31722064 0.29927771 0.30525869]
#  [0.10155709 0.34905007 0.2888816  0.24749298]
#  [0.17407773 0.15450234 0.3054079  0.24117516]
#  [0.31889087 0.0463771  0.01301827 0.12483687]]

# %% [markdown]
# ### Search Algorithms

# %% [markdown]
# Function to calculate cumulated score. for eg: **s(w0, w1, w2) = P(w1|w0).P(w2|w1)**

# %%
def calculate_score(sentence):
    score = 1
    L = len(tmatrix)
    for i in range(len(sentence) - 1):
        r = sentence[i]
        c = sentence[i + 1]
        if c == -1:
            score = score * tmatrix[c][r - 1]
            # print(tmatrix[c][r - 1])
            break
        score = score * tmatrix[r][c - 1]
        # print(tmatrix[r][c - 1])
    return score

# %%
# example test
print(calculate_score([0, 1, 2]))
# Out:
# 0.015799204666223723

# %% [markdown]
# ***

# %% [markdown]
# **IDDFS (Iterative Deepening Depth-First Search)**

# %%
def iddfs(maxdepth):
    L = len(vocab)

    # initialize best_sentence and best_score
    best_sentence = []
    best_score = -float('inf')
    
    # iddfs
    for depth in range(1, maxdepth + 1):
        print(f"Running DFS with depth: {depth}")  # Debug output
        print("best sentence upto now", best_sentence)
        best_sentence, best_score = dfs_iterative([0], best_score, L, depth)

    best_sentence = " ".join([("<sos>" if w == 0 else ("<eos>" if w == -1 else vocab[w-1])) for w in best_sentence])
    return best_sentence, best_score

def dfs_iterative(start_sentence, best_score, L, max_depth):
    stack = [(start_sentence, 0)]  # stack of tuples (current_sentence, current_depth)
    local_best_sentence = []
    local_best_score = -float('inf')
    
    while stack:
        current_sentence, depth = stack.pop()
        
        # print(f"Current Sentence: {current_sentence}, Depth: {depth}")
        
        # if we have reached the maximum depth, calculate the score
        if depth == max_depth:
            sentence_with_eos = current_sentence + [-1]
            score = calculate_score(sentence_with_eos)
            print(f"Evaluating Sentence: {sentence_with_eos}, Score: {score}")  # Debug output
            if score > local_best_score:
                local_best_score = score
                local_best_sentence = sentence_with_eos
        else:
            # add each possible word to the stack for further exploration
            for word_index in range(1, L+1):
                new_sentence = current_sentence + [word_index]
                stack.append((new_sentence, depth + 1))

    print("local best sent", local_best_sentence)
    
    return local_best_sentence, local_best_score

# %%
sentence, score = iddfs(n)
print("Best Sentence:", sentence)
print("Best Score:", score)
# Out:
# Running DFS with depth: 1
# best sentence upto now []
# Evaluating Sentence: [0, 4, -1], Score: 0.029388037572980755
# Evaluating Sentence: [0, 3, -1], Score: 0.0027042004699956374
# Evaluating Sentence: [0, 2, -1], Score: 0.011758090909111805
# Evaluating Sentence: [0, 1, -1], Score: 0.0967300290763913
# local best sent [0, 1, -1]
# Running DFS with depth: 2
# best sentence upto now [0, 1, -1]
# Evaluating Sentence: [0, 4, 4, -1], Score: 0.0070876646621407255
# Evaluating Sentence: [0, 4, 3, -1], Score: 0.0009359684909508888
# Evaluating Sentence: [0, 4, 2, -1], Score: 0.001686810586648104
# Evaluating Sentence: [0, 4, 1, -1], Score: 0.013068116826336424
# Evaluating Sentence: [0, 3, 4, -1], Score: 0.006417877071266831
# Evaluating Sentence: [0, 3, 3, -1], Score: 0.0007811937469753655
# Evaluating Sentence: [0, 3, 2, -1], Score: 0.0033626131476973955
# Evaluating Sentence: [0, 3, 1, -1], Score: 0.006727256007573089
# Evaluating Sentence: [0, 2, 4, -1], Score: 0.009661491402355922
# Evaluating Sentence: [0, 2, 3, -1], Score: 0.000987781492666391
# Evaluating Sentence: [0, 2, 2, -1], Score: 0.003729909153310428
# Evaluating Sentence: [0, 2, 1, -1], Score: 0.002576327811557493
# Evaluating Sentence: [0, 1, 4, -1], Score: 0.010626267149805083
# Evaluating Sentence: [0, 1, 3, -1], Score: 0.0005504765712643536
# Evaluating Sentence: [0, 1, 2, -1], Score: 0.0007327212282698128
# Evaluating Sentence: [0, 1, 1, -1], Score: 0.020216825430600122
# local best sent [0, 1, 1, -1]
# Running DFS with depth: 3
# best sentence upto now [0, 1, 1, -1]
# Evaluating Sentence: [0, 4, 4, 4, -1], Score: 0.0017093686585301039
# Evaluating Sentence: [0, 4, 4, 3, -1], Score: 0.0002257323505087973
# Evaluating Sentence: [0, 4, 4, 2, -1], Score: 0.0004068168130322018
# Evaluating Sentence: [0, 4, 4, 1, -1], Score: 0.003151705165774934
# Evaluating Sentence: [0, 4, 3, 4, -1], Score: 0.0022213333605077055
# Evaluating Sentence: [0, 4, 3, 3, -1], Score: 0.00027038407122900276
# Evaluating Sentence: [0, 4, 3, 2, -1], Score: 0.001163856004176727
# Evaluating Sentence: [0, 4, 3, 1, -1], Score: 0.0023284145252953988
# Evaluating Sentence: [0, 4, 2, 4, -1], Score: 0.001386033337067869
# Evaluating Sentence: [0, 4, 2, 3, -1], Score: 0.0001417067015388979
# Evaluating Sentence: [0, 4, 2, 2, -1], Score: 0.0005350911381510114
# Evaluating Sentence: [0, 4, 2, 1, -1], Score: 0.0003695988626728007
# Evaluating Sentence: [0, 4, 1, 4, -1], Score: 0.001435596596707799
# Evaluating Sentence: [0, 4, 1, 3, -1], Score: 7.436875820395497e-05
# Evaluating Sentence: [0, 4, 1, 2, -1], Score: 9.898980392743055e-05
# Evaluating Sentence: [0, 4, 1, 1, -1], Score: 0.002731270104096488
# Evaluating Sentence: [0, 3, 4, 4, -1], Score: 0.001547832529171747
# Evaluating Sentence: [0, 3, 4, 3, -1], Score: 0.0002044005389126314
# Evaluating Sentence: [0, 3, 4, 2, -1], Score: 0.00036837243591835355
# Evaluating Sentence: [0, 3, 4, 1, -1], Score: 0.0028538675689420705
# Evaluating Sentence: [0, 3, 3, 4, -1], Score: 0.0018540065696158645
# Evaluating Sentence: [0, 3, 3, 3, -1], Score: 0.00022567249620897956
# Evaluating Sentence: [0, 3, 3, 2, -1], Score: 0.0009713970519658233
# Evaluating Sentence: [0, 3, 3, 1, -1], Score: 0.0019433804504246082
# Evaluating Sentence: [0, 3, 2, 4, -1], Score: 0.0027630215029849155
# Evaluating Sentence: [0, 3, 2, 3, -1], Score: 0.00028248863356875254
# local best sent [0, 1, 4, 1, -1]
# Running DFS with depth: 4
# best sentence upto now [0, 1, 4, 1, -1]
# Evaluating Sentence: [0, 4, 4, 4, 4, -1], Score: 0.00041225725962639966
# Evaluating Sentence: [0, 4, 4, 4, 3, -1], Score: 5.4441035738777e-05
# Evaluating Sentence: [0, 4, 4, 4, 2, -1], Score: 9.811410995145918e-05
# Evaluating Sentence: [0, 4, 4, 4, 1, -1], Score: 0.0007601129974560483
# Evaluating Sentence: [0, 4, 4, 3, 4, -1], Score: 0.0005357304285121713
# Evaluating Sentence: [0, 4, 4, 3, 3, -1], Score: 6.520992162530331e-05
# Evaluating Sentence: [0, 4, 4, 3, 2, -1], Score: 0.00028069315796056465
# Evaluating Sentence: [0, 4, 4, 3, 1, -1], Score: 0.0005615557455569671
# Evaluating Sentence: [0, 4, 4, 2, 4, -1], Score: 0.0003342768117567954
# Evaluating Sentence: [0, 4, 4, 2, 3, -1], Score: 3.4176136408957866e-05
# Evaluating Sentence: [0, 4, 4, 2, 2, -1], Score: 0.0001290506908288574
# Evaluating Sentence: [0, 4, 4, 2, 1, -1], Score: 8.913806482069616e-05
# Evaluating Sentence: [0, 4, 4, 1, 4, -1], Score: 0.00034623023882786373
# Evaluating Sentence: [0, 4, 4, 1, 3, -1], Score: 1.793589715476866e-05
# Evaluating Sentence: [0, 4, 4, 1, 2, -1], Score: 2.3873881795147256e-05
# Evaluating Sentence: [0, 4, 4, 1, 1, -1], Score: 0.0006587145042091572
# Evaluating Sentence: [0, 4, 3, 4, 4, -1], Score: 0.0005357304285121713
# Evaluating Sentence: [0, 4, 3, 4, 3, -1], Score: 7.074640585204567e-05
# Evaluating Sentence: [0, 4, 3, 4, 2, -1], Score: 0.00012749979033727503
# Evaluating Sentence: [0, 4, 3, 4, 1, -1], Score: 0.0009877707483279526
# Evaluating Sentence: [0, 4, 3, 3, 4, -1], Score: 0.0006417023258557432
# Evaluating Sentence: [0, 4, 3, 3, 3, -1], Score: 7.810898195952887e-05
# Evaluating Sentence: [0, 4, 3, 3, 2, -1], Score: 0.00033621657969908585
# Evaluating Sentence: [0, 4, 3, 3, 1, -1], Score: 0.0006726361036133956
# Evaluating Sentence: [0, 4, 3, 2, 4, -1], Score: 0.0009563274229509398
# Evaluating Sentence: [0, 4, 3, 2, 3, -1], Score: 9.777398643546218e-05
# Evaluating Sentence: [0, 4, 3, 2, 2, -1], Score: 0.00036919914947672355
# Evaluating Sentence: [0, 4, 3, 2, 1, -1], Score: 0.0002550137276013949
# Evaluating Sentence: [0, 4, 3, 1, 4, -1], Score: 0.00025578773228462004
# Evaluating Sentence: [0, 4, 3, 1, 3, -1], Score: 1.3250669482943011e-05
# Evaluating Sentence: [0, 4, 3, 1, 2, -1], Score: 1.763752959847002e-05
# Evaluating Sentence: [0, 4, 3, 1, 1, -1], Score: 0.0004866446380450822
# Evaluating Sentence: [0, 4, 2, 4, 4, -1], Score: 0.00033427681175679546
# Evaluating Sentence: [0, 4, 2, 4, 3, -1], Score: 4.414325140565886e-05
# Evaluating Sentence: [0, 4, 2, 4, 2, -1], Score: 7.955535311288722e-05
# Evaluating Sentence: [0, 4, 2, 4, 1, -1], Score: 0.0006163339600005385
# Evaluating Sentence: [0, 4, 2, 3, 4, -1], Score: 0.00033631241497891317
# Evaluating Sentence: [0, 4, 2, 3, 3, -1], Score: 4.0936458067722326e-05
# Evaluating Sentence: [0, 4, 2, 3, 2, -1], Score: 0.0001762091320516254
# Evaluating Sentence: [0, 4, 2, 3, 1, -1], Score: 0.0003525246259728871
# Evaluating Sentence: [0, 4, 2, 2, 4, -1], Score: 0.0004396783857757536
# Evaluating Sentence: [0, 4, 2, 2, 3, -1], Score: 4.495229091533623e-05
# Evaluating Sentence: [0, 4, 2, 2, 2, -1], Score: 0.0001697419546652847
# Evaluating Sentence: [0, 4, 2, 2, 1, -1], Score: 0.0001172443887015787
# Evaluating Sentence: [0, 4, 2, 1, 4, -1], Score: 4.060224410688064e-05
# Evaluating Sentence: [0, 4, 2, 1, 3, -1], Score: 2.103333541920592e-06
# Evaluating Sentence: [0, 4, 2, 1, 2, -1], Score: 2.799677982220695e-06
# Evaluating Sentence: [0, 4, 2, 1, 1, -1], Score: 7.724711506189408e-05
# Evaluating Sentence: [0, 4, 1, 4, 4, -1], Score: 0.0003462302388278637
# Evaluating Sentence: [0, 4, 1, 4, 3, -1], Score: 4.5721772911784974e-05
# Evaluating Sentence: [0, 4, 1, 4, 2, -1], Score: 8.24001783538311e-05
# Evaluating Sentence: [0, 4, 1, 4, 1, -1], Score: 0.000638373487670945
# Evaluating Sentence: [0, 4, 1, 3, 4, -1], Score: 0.00017649932147838126
# Evaluating Sentence: [0, 4, 1, 3, 3, -1], Score: 2.1483765543220342e-05
# Evaluating Sentence: [0, 4, 1, 3, 2, -1], Score: 9.247589699403868e-05
# Evaluating Sentence: [0, 4, 1, 3, 1, -1], Score: 0.0001850076135088142
# Evaluating Sentence: [0, 4, 1, 2, 4, -1], Score: 8.133881145829765e-05
# Evaluating Sentence: [0, 4, 1, 2, 3, -1], Score: 8.316001044558769e-06
# Evaluating Sentence: [0, 4, 1, 2, 2, -1], Score: 3.14016092074269e-05
# Evaluating Sentence: [0, 4, 1, 2, 1, -1], Score: 2.168976127929319e-05
# Evaluating Sentence: [0, 4, 1, 1, 4, -1], Score: 0.0003000433894368471
# Evaluating Sentence: [0, 4, 1, 1, 3, -1], Score: 1.554326217469136e-05
# Evaluating Sentence: [0, 4, 1, 1, 2, -1], Score: 2.0689124199784214e-05
# Evaluating Sentence: [0, 4, 1, 1, 1, -1], Score: 0.000570842492507971
# Evaluating Sentence: [0, 3, 4, 4, 4, -1], Score: 0.0003732987577914609
# Evaluating Sentence: [0, 3, 4, 4, 3, -1], Score: 4.9296332665149696e-05
# Evaluating Sentence: [0, 3, 4, 4, 2, -1], Score: 8.884228115203122e-05
# Evaluating Sentence: [0, 3, 4, 4, 1, -1], Score: 0.000688281967402173
# Evaluating Sentence: [0, 3, 4, 3, 4, -1], Score: 0.0004851036550718731
# Evaluating Sentence: [0, 3, 4, 3, 3, -1], Score: 5.904755385136076e-05
# Evaluating Sentence: [0, 3, 4, 3, 2, -1], Score: 0.00025416752462333395
# Evaluating Sentence: [0, 3, 4, 3, 1, -1], Score: 0.0005084884677035038
# Evaluating Sentence: [0, 3, 4, 2, 4, -1], Score: 0.0003026874983363202
# Evaluating Sentence: [0, 3, 4, 2, 3, -1], Score: 3.094647570096669e-05
# Evaluating Sentence: [0, 3, 4, 2, 2, -1], Score: 0.00011685534081849657
# Evaluating Sentence: [0, 3, 4, 2, 1, -1], Score: 8.071447644040412e-05
# Evaluating Sentence: [0, 3, 4, 1, 4, -1], Score: 0.0003135113210169065
# Evaluating Sentence: [0, 3, 4, 1, 3, -1], Score: 1.6240946572579854e-05
# Evaluating Sentence: [0, 3, 4, 1, 2, -1], Score: 2.1617788916234142e-05
# Evaluating Sentence: [0, 3, 4, 1, 1, -1], Score: 0.000596465678696201
# Evaluating Sentence: [0, 3, 3, 4, 4, -1], Score: 0.00044714033096665513
# Evaluating Sentence: [0, 3, 3, 4, 3, -1], Score: 5.9047553851360776e-05
# Evaluating Sentence: [0, 3, 3, 4, 2, -1], Score: 0.00010641601711502014
# Evaluating Sentence: [0, 3, 3, 4, 1, -1], Score: 0.0008244298173489074
# Evaluating Sentence: [0, 3, 3, 3, 4, -1], Score: 0.0005355883763445605
# Evaluating Sentence: [0, 3, 3, 3, 3, -1], Score: 6.519263081966001e-05
# Evaluating Sentence: [0, 3, 3, 3, 2, -1], Score: 0.0002806187304697974
# Evaluating Sentence: [0, 3, 3, 3, 1, -1], Score: 0.0005614068456501386
# Evaluating Sentence: [0, 3, 3, 2, 4, -1], Score: 0.0007981860608484305
# Evaluating Sentence: [0, 3, 3, 2, 3, -1], Score: 8.16057672439798e-05
# Evaluating Sentence: [0, 3, 3, 2, 2, -1], Score: 0.00030814719699252477
# Evaluating Sentence: [0, 3, 3, 2, 1, -1], Score: 0.0002128438417758038
# Evaluating Sentence: [0, 3, 3, 1, 4, -1], Score: 0.0002134898545684469
# Evaluating Sentence: [0, 3, 3, 1, 3, -1], Score: 1.1059496386246962e-05
# Evaluating Sentence: [0, 3, 3, 1, 2, -1], Score: 1.4720931278808048e-05
# Evaluating Sentence: [0, 3, 3, 1, 1, -1], Score: 0.0004061715238444451
# Evaluating Sentence: [0, 3, 2, 4, 4, -1], Score: 0.0006663721529145592
# Evaluating Sentence: [0, 3, 2, 4, 3, -1], Score: 8.799842657719e-05
# Evaluating Sentence: [0, 3, 2, 4, 2, -1], Score: 0.0001585915327213388
# Evaluating Sentence: [0, 3, 2, 4, 1, -1], Score: 0.0012286457612223694
# Evaluating Sentence: [0, 3, 2, 3, 4, -1], Score: 0.0006704300751331943
# Evaluating Sentence: [0, 3, 2, 3, 3, -1], Score: 8.16057672439798e-05
# Evaluating Sentence: [0, 3, 2, 3, 2, -1], Score: 0.00035126833378403027
# Evaluating Sentence: [0, 2, 4, 2, 2, -1], Score: 0.00017591438073687218
# Evaluating Sentence: [0, 2, 4, 2, 1, -1], Score: 0.00012150781504774039
# Evaluating Sentence: [0, 2, 4, 1, 4, -1], Score: 0.0004719608834683079
# Evaluating Sentence: [0, 2, 4, 1, 3, -1], Score: 2.4449169707472937e-05
# Evaluating Sentence: [0, 2, 4, 1, 2, -1], Score: 3.2543484306861965e-05
# Evaluating Sentence: [0, 2, 4, 1, 1, -1], Score: 0.0008979212226304331
# Evaluating Sentence: [0, 2, 3, 4, 4, -1], Score: 0.0005653871978157486
# Evaluating Sentence: [0, 2, 3, 4, 3, -1], Score: 7.466275953618908e-05
# Evaluating Sentence: [0, 2, 3, 4, 2, -1], Score: 0.0001345578771418425
# Evaluating Sentence: [0, 2, 3, 4, 1, -1], Score: 0.001042451400478586
# Evaluating Sentence: [0, 2, 3, 3, 4, -1], Score: 0.000677225448729919
# Evaluating Sentence: [0, 2, 3, 3, 3, -1], Score: 8.243291044151615e-05
# Evaluating Sentence: [0, 2, 3, 3, 2, -1], Score: 0.0003548287342632111
# Evaluating Sentence: [0, 2, 3, 3, 1, -1], Score: 0.000709871647253356
# Evaluating Sentence: [0, 2, 3, 2, 4, -1], Score: 0.0010092674469848672
# Evaluating Sentence: [0, 2, 3, 2, 3, -1], Score: 0.00010318652304955843
# Evaluating Sentence: [0, 2, 3, 2, 2, -1], Score: 0.0003896371410866389
# Evaluating Sentence: [0, 2, 3, 2, 1, -1], Score: 0.0002691306843509367
# Evaluating Sentence: [0, 2, 3, 1, 4, -1], Score: 0.0002699475361025915
# Evaluating Sentence: [0, 2, 3, 1, 3, -1], Score: 1.3984195202333176e-05
# Evaluating Sentence: [0, 2, 3, 1, 2, -1], Score: 1.8613901517159643e-05
# Evaluating Sentence: [0, 2, 3, 1, 1, -1], Score: 0.0005135841340961226
# Evaluating Sentence: [0, 2, 2, 4, 4, -1], Score: 0.0007391595415515409
# Evaluating Sentence: [0, 2, 2, 4, 3, -1], Score: 9.761043639287942e-05
# Evaluating Sentence: [0, 2, 2, 4, 2, -1], Score: 0.00017591438073687218
# Evaluating Sentence: [0, 2, 2, 4, 1, -1], Score: 0.0013628499234583315
# Evaluating Sentence: [0, 2, 2, 3, 4, -1], Score: 0.0007436607079248043
# Evaluating Sentence: [0, 2, 2, 3, 3, -1], Score: 9.051951111731994e-05
# Evaluating Sentence: [0, 2, 2, 3, 2, -1], Score: 0.000389637141086639
# Evaluating Sentence: [0, 2, 2, 3, 1, -1], Score: 0.0007795094716570646
# Evaluating Sentence: [0, 2, 2, 2, 4, -1], Score: 0.000972225600549814
# Evaluating Sentence: [0, 2, 2, 2, 3, -1], Score: 9.939940066451817e-05
# Evaluating Sentence: [0, 2, 2, 2, 2, -1], Score: 0.000375336789689552
# Evaluating Sentence: [0, 2, 2, 2, 1, -1], Score: 0.0002592531266129256
# Evaluating Sentence: [0, 2, 2, 1, 4, -1], Score: 8.978049055296327e-05
# Evaluating Sentence: [0, 2, 2, 1, 3, -1], Score: 4.6509330049107075e-06
# Evaluating Sentence: [0, 1, 1, 4, 1, -1], Score: 0.0009875857042965347
# Evaluating Sentence: [0, 1, 1, 3, 4, -1], Score: 0.0002730505105185952
# Evaluating Sentence: [0, 1, 1, 3, 3, -1], Score: 3.323612295108252e-05
# Evaluating Sentence: [0, 1, 1, 3, 2, -1], Score: 0.0001430633878554606
# Evaluating Sentence: [0, 1, 1, 3, 1, -1], Score: 0.00028621313042609197
# Evaluating Sentence: [0, 1, 1, 2, 4, -1], Score: 0.00012583393413432648
# Evaluating Sentence: [0, 1, 1, 2, 3, -1], Score: 1.2865139149943256e-05
# Evaluating Sentence: [0, 1, 1, 2, 2, -1], Score: 4.857936763367989e-05
# Evaluating Sentence: [0, 1, 1, 2, 1, -1], Score: 3.355480542775275e-05
# Evaluating Sentence: [0, 1, 1, 1, 4, -1], Score: 0.000464177425597048
# Evaluating Sentence: [0, 1, 1, 1, 3, -1], Score: 2.4045960269845517e-05
# Evaluating Sentence: [0, 1, 1, 1, 2, -1], Score: 3.2006785508383095e-05
# Evaluating Sentence: [0, 1, 1, 1, 1, -1], Score: 0.0008831129360692792
# local best sent [0, 2, 2, 4, 1, -1]
# Best Sentence: <sos> grass grass airport green <eos>
# Best Score: 0.0013628499234583315

# %% [markdown]
# ---

# %% [markdown]
# **Greedy Search**

# %%
def greedy_search(vocab, tmatrix, n, L):
    sentence = [0]  # start with <SoS>, which is indexed as 0
    current_word = 0  # start with <SoS>
    score = 1;

    for _ in range(n + 1):  # we need n words between <SoS> and <EoS>
        if len(sentence) == n + 1:
            sentence.append(-1)
            score = score * tmatrix[int(L) + 1][sentence[n]-1]
            break
        next_word = np.argmax(tmatrix[current_word]) + 1
        score = score * np.max(tmatrix[current_word])
        # print(score)
        # print(next_word, current_word)
        sentence.append(next_word)
        current_word = next_word

    s = ""
    for i in range(len(sentence)):
        if sentence[i] == 0:
            s = s + "<sos> "
        elif sentence[i] == -1:
            s = s + "<eos>"
        else:
            s = s + vocab[sentence[i]-1] + " "
    return s, score

# %%
sentence, score = greedy_search(vocab, tmatrix, n, L)
print("Best Sentence", sentence)
print("Best Score", score)
# Out:
# Best Sentence <sos> green airport at grass <eos>
# Best Score 0.00042083261917621675

# %% [markdown]
# ---

# %% [markdown]
# **UCS (Uniform Cost Search)**

# %%
def uniform_cost_search(vocab, tmatrix, n):
    # priority queue to store (-cumulative_score, current_word_index, path)
    pq = [(-1, 0, [0])]  # start with <SoS> which is indexed as 0
    best_score = {}

    while pq:
        current_score, idx, path = heapq.heappop(pq)
        current_score = -current_score
        print(path)
        print(current_score)

        # if we have reached the end of the sentence
        if len(path) == n + 2:  # n words + <SoS> + <EoS>
            path[len(path) - 1] = -1
            print(path)
            s = ""
            for i in range(len(path)):
                if path[i] == 0:
                    s = s + "<sos> "
                elif path[i] == -1:
                    s = s + "<eos>"
                else:
                    s = s + vocab[path[i]-1] + " "

            return s, current_score

        # expand to the next word
        if(len(path) != n+1):
            current_word = path[-1]
            for next_word in range(1, len(vocab) + 1):
                new_path = path + [next_word]
                new_score = calculate_score(new_path)
    
                if tuple(new_path) not in best_score or new_score > best_score[tuple(new_path)]:
                    best_score[tuple(new_path)] = new_score
                    heapq.heappush(pq, (-new_score, idx + 1, new_path))
        else:
            current_word = path[-1]
            new_path = path + [-1]
            new_score = calculate_score(new_path)
    
            if tuple(new_path) not in best_score or new_score > best_score[tuple(new_path)]:
                best_score[tuple(new_path)] = new_score
                heapq.heappush(pq, (-new_score, idx + 1, new_path))

    return None, float('-inf')  # If no valid sentence is found

sentence, score = uniform_cost_search(vocab, tmatrix, n)
print(sentence)
print(score)
# Out:
# [0]
# 1
# [0, 1]
# 0.3033326997402268
# [0, 2]
# 0.25353228156877655
# [0, 4]
# 0.2354115187226763
# [0, 3]
# 0.20772349996832032
# [0, 1, 4]
# 0.08512122260209748
# [0, 2, 2]
# 0.08042567326556672
# [0, 2, 4]
# 0.07739293100148292
# [0, 2, 3]
# 0.075876559869441
# [0, 3, 2]
# 0.072505901677306
# [0, 4, 3]
# 0.07189653761161406
# [0, 1, 1]
# 0.06339731618603986
# [0, 3, 3]
# 0.06000749614371272
# [0, 4, 4]
# 0.056775410680896275
# [0, 3, 4]
# 0.05141010809484703
# [0, 1, 3]
# 0.04228492720947441
# [0, 4, 1]
# 0.04097990246981942
# [0, 4, 2]
# 0.03637163038736578
# [0, 2, 3, 2]
# 0.02648471834118402
# [0, 1, 4, 3]
# 0.025996693855782706
# [0, 2, 2, 2]
# 0.0255126837505504
# [0, 4, 3, 2]
# 0.02509549130359078
# [0, 2, 2, 4]
# 0.02455063530085934
# [0, 2, 2, 3]
# 0.024069611076013804
# [0, 2, 4, 3]
# 0.02363641254604923
# [0, 3, 2, 2]
# 0.023000368718499593
# [0, 3, 2, 4]
# 0.022133056236429652
# [0, 2, 3, 3]
# 0.021919341694406583
# [0, 3, 2, 3]
# 0.021699399995394678
# [0, 3, 1]
# 0.021095793582458965
# [0, 3, 3, 2]
# 0.02094562057716582
# [0, 4, 3, 3]
# 0.02076958651348163
# [0, 1, 4, 4]
# 0.020529124475796308
# [0, 2, 3, 4]
# 0.01877891594041119
# [0, 2, 4, 4]
# 0.01866525251291454
# [0, 4, 3, 4]
# 0.017793888369982302
# [0, 1, 1, 4]
# 0.0177905549519355
# [0, 4, 4, 3]
# 0.01733965895799089
# [0, 3, 3, 3]
# 0.01733506124240573
# [0, 1, 2]
# 0.015799204666223723
# [0, 3, 4, 3]
# 0.01570105316134759
# [0, 3, 3, 4]
# 0.014851434063646512
# [0, 1, 4, 1]
# 0.014817709087782766
# [0, 1, 3, 2]
# 0.014759556695076729
# [0, 4, 4, 4]
# 0.01369281875192256
# [0, 2, 4, 1]
# 0.013472385639848176
# [0, 1, 1, 1]
# 0.013250202510427524
# [0, 1, 4, 2]
# 0.013151428032930616
# [0, 3, 4, 4]
# 0.012398841042577456
# [0, 1, 3, 3]
# 0.012215337248056608
# [0, 2, 4, 2]
# 0.011957388900315054
# [0, 4, 2, 2]
# 0.01153783196194961
# 0.0018780660529076477
# [0, 3, 4, 1, 1]
# 0.0018704382325618874
# [0, 1, 1, 1, 3]
# 0.0018470934691315784
# [0, 1, 3, 4, 1]
# 0.0018217621899183304
# [0, 3, 1, 4, 3]
# 0.0018079847239603154
# [0, 4, 1, 1, 1]
# 0.0017900872772625338
# [0, 4, 1, 4, 2]
# 0.0017767429577816565
# [0, 4, 4, 3, 1]
# 0.0017609652553697494
# [0, 3, 3, 3, 1]
# 0.0017604983247675298
# [0, 4, 2, 4, 2]
# 0.0017154017894256593
# [0, 3, 3, 1, 4]
# 0.0017101506274800858
# [0, 2, 1, 1]
# 0.0016885373697056259
# [0, 1, 2, 3, 2]
# 0.00165043079725587
# [0, 4, 1, 3, 3]
# 0.001650278158240144
# [0, 1, 3, 4, 2]
# 0.0016169013841403502
# [0, 2, 3, 1, 1]
# 0.001610532566015181
# [0, 3, 4, 3, 1]
# 0.0015945532237301918
# [0, 1, 2, 2, 2]
# 0.0015898571561201414
# [0, 1, 2, 2, 4]
# 0.0015299058147704638
# [0, 4, 3, 1, 1]
# 0.0015260538354200538
# [0, 1, 2, 2, 3]
# 0.0014999301440956248
# [0, 1, 2, 4, 3]
# 0.001472934795835956
# [0, 3, 1, 4, 4]
# 0.0014277332207865878
# [0, 4, 1, 3, 4]
# 0.0014138396692723876
# [0, 4, 4, 1, 3]
# 0.0013777482007709268
# [0, 1, 2, 3, 3]
# 0.001365933219375366
# [0, 2, 2, 4, 1, -1]
# 0.0013628499234583315
# [0, 2, 2, 4, 1, -1]
# <sos> grass grass airport green <eos>
# 0.0013628499234583315

# %% [markdown]
# ---

# %% [markdown]
# **A\* Search**

# %% [markdown]
# h(x) calculates proximity score to goal

# %%
def h_heuristic(path, n, vocab_size, tmatrix):
    remaining_words = (n + 2) - len(path)  # remaining words to complete the sentence including <EoS>

    # print(path[-1] - 1)
    # print(vocab_size + 1)
    # print(remaining_words)
    
    if remaining_words == 1:  # only <EoS> is left to predict
        return float(tmatrix[vocab_size + 1][path[-1] - 1])
    
    # if more than one word is left, we optimistically assume the best-case transitions
    max_prob = 1
    row = path[-1]
    last_word = -1
    for _ in range(remaining_words - 1):
        max_prob *= max(tmatrix[row])  # best possible transition at each step
        # print(max_prob)
        row = np.argmax(tmatrix[row])
        last_word = row 
        # print("row", row)
        # print("last word", last_word) 
    
    # final transition to <EoS>
    max_prob *= tmatrix[vocab_size + 1][last_word]
    
    return max_prob

# %%
def a_star_search(vocab, tmatrix, n):
    vocab_size = len(vocab)
    # Priority queue to store (-(g+h), g, current_word_index, path)
    pq = [(-(1 + h_heuristic([0], n, vocab_size, tmatrix)), 1, 0, [0])]  # Start with <SoS> which is indexed as 0 in the vocabulary
    best_score = {}

    while pq:
        # Pop the element with the highest priority (lowest g+h value)
        f_score, g_score, idx, path = heapq.heappop(pq)
        g_score = -g_score  # Convert back to positive accumulated score
        print(f"Path: {path}, g: {g_score}, f: {-f_score}")

        # If we've reached the end of the sentence (i.e., we have n words + <EoS>)
        if len(path) == n + 2:
            g_score = calculate_score(path)
            sentence = " ".join([("<sos>" if w == 0 else ("<eos>" if w == -1 else vocab[w-1])) for w in path])
            return sentence, g_score

        # Expand to the next word
        if len(path) != n + 1:
            current_word = path[-1]
            for next_word in range(1, vocab_size + 1):  # Exclude <SoS> which is index 0
                new_path = path + [next_word]
                new_g = calculate_score(new_path)  # Update g (accumulated score)
                h_score = h_heuristic(new_path, n, vocab_size, tmatrix)  # Calculate heuristic h
    
                if tuple(new_path) not in best_score or new_g > best_score[tuple(new_path)]:
                    best_score[tuple(new_path)] = new_g

                    # Push new (f = g + h, g, current index, path) to priority queue
                    heapq.heappush(pq, (-(new_g + h_score), -new_g, idx + 1, new_path))
                    
        # for last word
        else:
            current_word = path[-1]
            new_path = path + [-1]
            new_g = calculate_score(new_path)  # Update g (accumulated score)
            h_score = 0  # Calculate heuristic h

            if tuple(new_path) not in best_score or new_g > best_score[tuple(new_path)]:
                best_score[tuple(new_path)] = new_g
                # Push new (f = g + h, g, current index, path) to priority queue
                heapq.heappush(pq, (-(new_g + h_score), -new_g, idx + 1, new_path))            

    return None, float('-inf')  # If no valid sentence is found

sentence, score = a_star_search(vocab, tmatrix, n)
print(f"Best Sentence: {sentence}")
print(f"Best Score: {score}")
# Out:
# Path: [0], g: -1, f: 1.0026997217767637
# Path: [0, 1], g: 0.3033326997402268, f: 0.30676407209698425
# Path: [0, 2], g: 0.25353228156877655, f: 0.2549733059804652
# Path: [0, 4], g: 0.2354115187226763, f: 0.23880545127363254
# Path: [0, 3], g: 0.20772349996832032, f: 0.20930911452377846
# Path: [0, 2, 2], g: 0.08042567326556672, f: 0.09153845898243926
# Path: [0, 1, 4], g: 0.08512122260209748, f: 0.08961431403539102
# Path: [0, 2, 3], g: 0.075876559869441, f: 0.08810438518692612
# Path: [0, 4, 3], g: 0.07189653761161406, f: 0.0841243629290992
# Path: [0, 3, 2], g: 0.072505901677306, f: 0.08361868739417855
# Path: [0, 2, 4], g: 0.07739293100148292, f: 0.08188602243477647
# Path: [0, 3, 3], g: 0.06000749614371272, f: 0.07223532146119785
# Path: [0, 1, 1], g: 0.06339731618603986, f: 0.06793997267938802
# Path: [0, 4, 4], g: 0.056775410680896275, f: 0.06126850211418981
# Path: [0, 3, 4], g: 0.05141010809484703, f: 0.05590319952814057
# Path: [0, 1, 3], g: 0.04228492720947441, f: 0.054512752526959536
# Path: [0, 1, 4, 1], g: 0.014817709087782766, f: 0.04984943220535428
# Path: [0, 1, 4, 1, 1], g: 0.003096939396891341, f: 0.3219878112324389
# Path: [0, 1, 4, 1, 4], g: 0.0041581455438020835, f: 0.12899501730113092
# Path: [0, 2, 4, 1], g: 0.013472385639848176, f: 0.048504108757419694
# Path: [0, 2, 4, 1, 1], g: 0.0028157633282569847, f: 0.3217066351638046
# Path: [0, 2, 4, 1, 4], g: 0.0037806208760642096, f: 0.12861749263339303
# Path: [0, 1, 1, 1], g: 0.013250202510427524, f: 0.04828192562799904
# Path: [0, 3, 3, 1, 1], g: 0.001273700691106355, f: 0.3201645725266539
# Path: [0, 3, 3, 1, 4], g: 0.0017101506274800858, f: 0.12654702238480892
# Path: [0, 3, 3, 1, 2], g: 0.0003174181355445313, f: 0.046694513929249795
# Path: [0, 2, 2, 3], g: 0.024069611076013804, f: 0.04025753949148063
# Path: [0, 2, 2, 3, 1], g: 0.0024444395889107124, f: 0.3213353114244583
# Path: [0, 2, 2, 3, 4], g: 0.005957059780946858, f: 0.13079393153827568
# Path: [0, 2, 2, 3, 2], g: 0.008401499369857571, f: 0.05477859516356283
# Path: [0, 2, 2, 2], g: 0.0255126837505504, f: 0.040224455877677354
# Path: [0, 2, 2, 2, 1], g: 0.0008129838434090479, f: 0.31970385567895665
# Path: [0, 2, 2, 2, 4], g: 0.007787968305067188, f: 0.13262484006239603
# Path: [0, 2, 2, 2, 2], g: 0.0080931499324392, f: 0.054470245726144464
# Path: [0, 2, 4, 3], g: 0.02363641254604923, f: 0.03982434096151606
# Path: [0, 2, 4, 3, 1], g: 0.0024004452080642934, f: 0.3212913170436119
# Path: [0, 2, 4, 3, 4], g: 0.005849846185684867, f: 0.1306867179430137
# Path: [0, 2, 4, 3, 2], g: 0.008250291393749162, f: 0.054627387187454426
# Path: [0, 4, 3, 2], g: 0.02509549130359078, f: 0.03980726343071773
# Path: [0, 4, 3, 2, 1], g: 0.0007996896434618102, f: 0.3196905614790094
# Path: [0, 4, 3, 2, 4], g: 0.007660616687111085, f: 0.13249748844443993
# Path: [0, 4, 3, 2, 2], g: 0.007960807876349056, f: 0.05433790367005432
# Path: [0, 1, 3, 1], g: 0.004294334036333963, f: 0.039326057153905476
# Path: [0, 1, 3, 1, 1], g: 0.0008975268836597256, f: 0.31978839871920733
# Path: [0, 1, 3, 1, 4], g: 0.0012050760229529935, f: 0.12604194778028183
# Path: [0, 1, 3, 1, 2], g: 0.00022367210130419475, f: 0.04660076789500946
# Path: [0, 2, 3, 3], g: 0.021919341694406583, f: 0.038107270109873415
# Path: [0, 2, 3, 3, 1], g: 0.002226064493998554, f: 0.32111693632954613
# Path: [0, 2, 3, 3, 4], g: 0.00542488320314836, f: 0.13026175496047718
# Path: [0, 2, 3, 3, 2], g: 0.007650947697146915, f: 0.054028043490852176
# Path: [0, 3, 2, 3], g: 0.021699399995394678, f: 0.03788732841086151
# Path: [0, 3, 2, 3, 1], g: 0.002203727855711417, f: 0.32109459969125903
# Path: [0, 3, 2, 3, 4], g: 0.005370449176557769, f: 0.1302073209338866
# Path: [0, 3, 2, 3, 2], g: 0.007574177032269186, f: 0.05395127282597445
# Path: [0, 3, 2, 2], g: 0.023000368718499593, f: 0.037712140845626546
# Path: [0, 3, 2, 2, 1], g: 0.0007329267412013303, f: 0.31962379857674894
# Path: [0, 3, 2, 2, 4], g: 0.007021062320841462, f: 0.13185793407817029
# Path: [0, 3, 2, 2, 2], g: 0.007296191743692422, f: 0.05367328753739768
# Path: [0, 2, 2, 1], g: 0.0025628339848327466, f: 0.03759455710240426
# Path: [0, 2, 2, 1, 1], g: 0.0005356389093820572, f: 0.31942651074492967
# Path: [0, 2, 2, 1, 4], g: 0.0007191824762117407, f: 0.12555605423354058
# Path: [0, 2, 2, 1, 2], g: 0.00013348623042158794, f: 0.04651058202412685
# Path: [0, 3, 2, 1], g: 0.0023104635792846797, f: 0.0373421866968562
# Path: [0, 3, 2, 1, 1], g: 0.00048289284405434303, f: 0.31937376467960193
# Path: [0, 3, 2, 1, 4], g: 0.0006483622926732175, f: 0.12548523405000203
# Path: [0, 3, 2, 1, 2], g: 0.00012034141717736318, f: 0.046497437210882626
# Path: [0, 4, 3, 3], g: 0.02076958651348163, f: 0.03695751492894846
# Path: [0, 4, 3, 3, 1], g: 0.002109298706926534, f: 0.32100017054247415
# Path: [0, 4, 3, 3, 4], g: 0.005140326866754178, f: 0.129977198624083
# Path: [0, 4, 3, 3, 2], g: 0.007249625573680712, f: 0.05362672136738597
# Path: [0, 4, 2, 1], g: 0.001159013616618676, f: 0.03619073673419019
# Path: [0, 4, 2, 1, 1], g: 0.0002422368336141353, f: 0.3191331086691617
# Path: [0, 4, 2, 1, 4], g: 0.0003252424026277076, f: 0.12516211415995654
# Path: [0, 4, 2, 1, 2], g: 6.0367686555325307e-05, f: 0.046437463480260587
# Path: [0, 3, 3, 2], g: 0.02094562057716582, f: 0.03565739270429277
# Path: [0, 3, 3, 2, 1], g: 0.0006674504056847624, f: 0.3195583222412324
# Path: [0, 3, 3, 2, 4], g: 0.0063938326042006985, f: 0.13123070436152953
# Path: [0, 3, 3, 2, 2], g: 0.006644383218026978, f: 0.05302147901173224
# Path: [0, 4, 4, 3], g: 0.01733965895799089, f: 0.03352758737345772
# Path: [0, 4, 4, 3, 1], g: 0.0017609652553697494, f: 0.3206518370909173
# Path: [0, 4, 4, 3, 4], g: 0.0042914438736784515, f: 0.12912831563100727
# Path: [0, 4, 4, 3, 2], g: 0.006052409129048201, f: 0.05242950492275346
# Path: [0, 3, 3, 3], g: 0.01733506124240573, f: 0.03352298965787256
# Path: [0, 3, 3, 3, 1], g: 0.0017604983247675298, f: 0.32065137016031514
# Path: [0, 3, 3, 3, 4], g: 0.004290305971345502, f: 0.12912717772867432
# Path: [0, 3, 3, 3, 2], g: 0.006050804296113032, f: 0.05242790008981829
# Path: [0, 3, 4, 3], g: 0.01570105316134759, f: 0.03188898157681442
# Path: [0, 3, 4, 3, 1], g: 0.0015945532237301918, f: 0.3204854250592778
# Path: [0, 3, 4, 3, 4], g: 0.0038859004414566645, f: 0.1287227721987855
# Path: [0, 3, 4, 3, 2], g: 0.005480453665186857, f: 0.05185754945889212
# Path: [0, 1, 3, 2], g: 0.014759556695076729, f: 0.029471328822203678
# Path: [0, 1, 3, 2, 1], g: 0.0004703261031375563, f: 0.31936119793868517
# Path: [0, 1, 3, 2, 4], g: 0.004505482875184386, f: 0.1293423546325132
# Path: [0, 1, 3, 2, 2], g: 0.0046820360585160216, f: 0.05105913185222128
# Path: [0, 2, 2, 4], g: 0.02455063530085934, f: 0.028526517602750844
# Path: [0, 2, 2, 4, 1], g: 0.0042737188293089645, f: 0.3231645906648566
# Path: [0, 2, 2, 4, 4], g: 0.005921003395442315, f: 0.13075787515277115
# Path: [0, 2, 2, 4, 2], g: 0.003793130590138181, f: 0.05017022638384344
# Path: [0, 1, 3, 3], g: 0.012215337248056608, f: 0.028403265663523435
# Path: [0, 1, 3, 3, 1], g: 0.0012405540690601925, f: 0.3201314259046078
# Path: [0, 1, 3, 3, 4], g: 0.0030232102214404043, f: 0.12786008197876922
# Path: [0, 1, 3, 3, 2], g: 0.004263764290500597, f: 0.05064086008420586
# Path: [0, 1, 4, 2], g: 0.013151428032930616, f: 0.027863200160057566
# Path: [0, 1, 4, 2, 1], g: 0.00041908168552823316, f: 0.31930995352107583
# Path: [0, 1, 4, 2, 4], g: 0.004014587633675588, f: 0.12885145939100442
# Path: [0, 1, 4, 2, 2], g: 0.00417190445101234, f: 0.050549000244717604
# Path: [0, 4, 2, 3], g: 0.010885218140899709, f: 0.027073146556366535
# Path: [0, 4, 2, 3, 1], g: 0.0011054710470191334, f: 0.31999634288256673
# Path: [0, 4, 2, 3, 4], g: 0.002694015079396358, f: 0.12753088683672517
# Path: [0, 4, 2, 3, 2], g: 0.0037994861264154917, f: 0.050176581920120755
# Path: [0, 1, 2], g: 0.015799204666223723, f: 0.026911990383096263
# Path: [0, 1, 2, 1], g: 0.0005034553894031483, f: 0.035535178506974664
# Path: [0, 1, 2, 1, 1], g: 0.00010522347420799488, f: 0.3189960953097556
# Path: [0, 1, 2, 1, 4], g: 0.00014127965203986157, f: 0.12497815140936869
# Path: [0, 1, 2, 1, 2], g: 2.6222674786812135e-05, f: 0.04640331846849207
# Path: [0, 2, 4, 2], g: 0.011957388900315054, f: 0.026669161027442004
# Path: [0, 2, 4, 2, 1], g: 0.0003810325907052056, f: 0.3192719044262528
# Path: [0, 2, 4, 2, 4], g: 0.0036500968176273038, f: 0.12848696857495612
# Path: [0, 2, 4, 2, 2], g: 0.0037931305901381805, f: 0.05017022638384344
# Path: [0, 4, 2, 2], g: 0.01153783196194961, f: 0.02624960408907656
# Path: [0, 4, 2, 2, 1], g: 0.0003676630441840987, f: 0.3192585348797317
# Path: [0, 4, 2, 2, 4], g: 0.0035220234181328027, f: 0.12835889517546162
# Path: [0, 4, 2, 2, 2], g: 0.003660038468564987, f: 0.05003713426227025
# Path: [0, 3, 2, 4], g: 0.022133056236429652, f: 0.026108938538321157
# Path: [0, 3, 2, 4, 1], g: 0.0038528721570179766, f: 0.32274374399256556
# Path: [0, 3, 2, 4, 4], g: 0.005337943377898191, f: 0.13017481513522702
# Path: [0, 3, 2, 4, 2], g: 0.003419608968763075, f: 0.049796704762468336
# Path: [0, 3, 1], g: 0.021095793582458965, f: 0.02563845007580713
# Path: [0, 3, 1, 1], g: 0.004409075240117339, f: 0.03944079835768886
# Path: [0, 3, 1, 1, 1], g: 0.0009215080910338439, f: 0.31981237992658146
# Path: [0, 3, 1, 1, 4], g: 0.0012372746997103682, f: 0.12607414645703918
# Path: [0, 3, 1, 1, 2], g: 0.00022964844267383587, f: 0.046606744236379095
# Path: [0, 1, 1, 3], g: 0.008837658790161813, f: 0.02502558720562864
# Path: [0, 1, 1, 3, 1], g: 0.0008975268836597255, f: 0.31978839871920733
# Path: [0, 1, 1, 3, 4], g: 0.0021872585132490328, f: 0.12702413027057785
# Path: [0, 1, 1, 3, 2], g: 0.0030847853969087585, f: 0.04946188119061402
# Path: [0, 1, 4, 4], g: 0.020529124475796308, f: 0.024505006777687813
# Path: [0, 1, 4, 4, 1], g: 0.003573663359268231, f: 0.3224645351948158
# Path: [0, 1, 4, 4, 4], g: 0.004951114878986174, f: 0.129787986636315
# Path: [0, 1, 4, 4, 2], g: 0.0031717977593505196, f: 0.04954889355305578
# Path: [0, 4, 4, 2], g: 0.00877193377614255, f: 0.0234837059032695
# Path: [0, 4, 4, 2, 1], g: 0.00027952529436673485, f: 0.31917039712991435
# Path: [0, 4, 4, 2, 4], g: 0.0026777089737285167, f: 0.12751458073105734
# Path: [0, 4, 4, 2, 2], g: 0.0027826384688446446, f: 0.04915973426254991
# Path: [0, 2, 3, 4], g: 0.01877891594041119, f: 0.02275479824230269
# Path: [0, 2, 3, 4, 1], g: 0.0032689910328200914, f: 0.3221598628683677
# Path: [0, 2, 3, 4, 4], g: 0.004529008055527122, f: 0.12936587981285594
# Path: [0, 2, 3, 4, 2], g: 0.0029013864460246336, f: 0.049278482239729894
# Path: [0, 3, 4, 2], g: 0.007942981974484753, f: 0.022654754101611704
# Path: [0, 3, 4, 2, 1], g: 0.00025311002467962983, f: 0.31914398186022724
# Path: [0, 3, 4, 2, 4], g: 0.002424664236418198, f: 0.12726153599374704
# Path: [0, 3, 4, 2, 2], g: 0.002519677845682551, f: 0.04889677363938781
# Path: [0, 2, 4, 4], g: 0.01866525251291454, f: 0.022641134814806042
# Path: [0, 2, 4, 4, 1], g: 0.0032492047615345077, f: 0.3221400765970821
# Path: [0, 2, 4, 4, 4], g: 0.004501595260220692, f: 0.12933846701754953
# Path: [0, 2, 4, 4, 2], g: 0.0028838251805610713, f: 0.049260920974266334
# Path: [0, 4, 1, 3], g: 0.00571264553565002, f: 0.021900573951116848
# Path: [0, 4, 1, 3, 1], g: 0.0005801596403305732, f: 0.3194710314758782
# Path: [0, 4, 1, 3, 4], g: 0.0014138396692723876, f: 0.12625071142660121
# Path: [0, 4, 1, 3, 2], g: 0.001993999309602961, f: 0.048371095103308226
# Path: [0, 4, 3, 4], g: 0.017793888369982302, f: 0.021769770671873807
# Path: [0, 4, 3, 4, 1], g: 0.0030975196707334635, f: 0.32198839150628106
# Path: [0, 4, 3, 4, 4], g: 0.0042914438736784515, f: 0.12912831563100727
# Path: [0, 4, 3, 4, 2], g: 0.0027491973819236113, f: 0.049126293175628874
# Path: [0, 1, 1, 4], g: 0.0177905549519355, f: 0.021766437253827
# Path: [0, 1, 1, 4, 1], g: 0.003096939396891341, f: 0.3219878112324389
# Path: [0, 1, 1, 4, 4], g: 0.004290639936047849, f: 0.12912751169337666
# Path: [0, 1, 1, 4, 2], g: 0.0027486823610368563, f: 0.04912577815474212
# Path: [0, 2, 3, 2, 3], g: 0.007926285774756415, f: 0.020944555110715284
# Path: [0, 1, 2, 3], g: 0.004728349744373978, f: 0.020916278159840807
# Path: [0, 1, 2, 3, 1], g: 0.0004801974269073964, f: 0.319371069262455
# Path: [0, 1, 2, 3, 4], g: 0.0011702333703484736, f: 0.1260071051276773
# Path: [0, 1, 2, 3, 2], g: 0.00165043079725587, f: 0.04802752659096113
# Path: [0, 2, 2, 2, 3], g: 0.00763537749138118, f: 0.02065364682734005
# Path: [0, 4, 3, 2, 3], g: 0.007510521092492097, f: 0.020528790428450967
# Path: [0, 1, 4, 3, 3], g: 0.0075099664050436, f: 0.02052823574100247
# Path: [0, 2, 2, 4, 3], g: 0.007497957975355551, f: 0.02051622731131442
# Path: [0, 2, 2, 3, 3], g: 0.00695326765649934, f: 0.01997153699245821
# Path: [0, 3, 2, 2, 3], g: 0.00688349760941598, f: 0.01990176694537485
# Path: [0, 2, 4, 3, 3], g: 0.006828124573890604, f: 0.019846393909849474
# Path: [0, 3, 2, 4, 3], g: 0.006759610229765493, f: 0.01977787956572436
# Path: [0, 1, 2, 2], g: 0.005011833855945598, f: 0.019723605983072545
# Path: [0, 1, 2, 2, 1], g: 0.00015970644212004304, f: 0.31905057827766764
# Path: [0, 1, 2, 2, 4], g: 0.0015299058147704638, f: 0.1263667775720993
# Path: [0, 1, 2, 2, 2], g: 0.0015898571561201414, f: 0.047966952949825406
# Path: [0, 2, 3, 3, 3], g: 0.006332094406268059, f: 0.019350363742226928
# Path: [0, 1, 4, 4, 3], g: 0.00626975679871616, f: 0.019288026134675028
# Path: [0, 3, 2, 3, 3], g: 0.006268557297287557, f: 0.019286826633246427
# Path: [0, 3, 3, 2, 3], g: 0.006268557297287557, f: 0.019286826633246427
# Path: [0, 3, 1, 3], g: 0.00294077788785815, f: 0.01912870630332498
# Path: [0, 3, 1, 3, 1], g: 0.0002986568361479397, f: 0.31918952867169553
# Path: [0, 3, 1, 3, 4], g: 0.0007278218839985876, f: 0.1255646936413274
# Path: [0, 3, 1, 3, 2], g: 0.0010264787201465274, f: 0.04740357451385179
# Path: [0, 4, 3, 3, 3], g: 0.005999951294891204, f: 0.019018220630850072
# Path: [0, 3, 3, 4], g: 0.014851434063646512, f: 0.018827316365538013
# Path: [0, 3, 3, 4, 1], g: 0.0025853039085234992, f: 0.3214761757440711
# Path: [0, 3, 3, 4, 4], g: 0.0035817969857163197, f: 0.12841866874304514
# Path: [0, 3, 3, 4, 2], g: 0.0022945813077295783, f: 0.04867167710143484
# Path: [0, 2, 3, 4, 3], g: 0.0057352292850445736, f: 0.018753498621003444
# Path: [0, 2, 4, 4, 3], g: 0.005700515576325398, f: 0.018718784912284268
# Path: [0, 4, 3, 4, 3], g: 0.005434394083139071, f: 0.018452663419097938
# Path: [0, 4, 2, 1, 3], g: 0.00016156783114870695, f: 0.013179837167107576
# Path: [0, 1, 2, 1, 3], g: 7.018226031140457e-05, f: 0.013088451596270274
# Path: [0, 2, 1], g: 0.008079026523174073, f: 0.01262168301652224
# Path: [0, 2, 1, 1], g: 0.0016885373697056259, f: 0.03672026048727714
# Path: [0, 2, 1, 1, 1], g: 0.0003529086630318718, f: 0.3192437804985795
# Path: [0, 2, 1, 1, 4], g: 0.000473837358918979, f: 0.1253107091162478
# Path: [0, 2, 1, 1, 2], g: 8.794814246335072e-05, f: 0.04646504393616861
# Path: [0, 2, 1, 3], g: 0.0011262255890920829, f: 0.01731415400455891
# Path: [0, 2, 1, 3, 1], g: 0.00011437619026442954, f: 0.31900524802581204
# Path: [0, 2, 1, 3, 4], g: 0.0002787329275851645, f: 0.12511560468491398
# Path: [0, 2, 1, 3, 2], g: 0.0003931091178495941, f: 0.046770204911554855
# Path: [0, 2, 1, 2], g: 0.00042079931920557665, f: 0.015132571446332526
# Path: [0, 2, 1, 2, 1], g: 1.3409136066458712e-05, f: 0.31890428097161405
# Path: [0, 2, 1, 2, 4], g: 0.0001284526470366404, f: 0.12496532440436546
# Path: [0, 2, 1, 2, 2], g: 0.00013348623042158797, f: 0.04651058202412685
# Path: [0, 2, 1, 3, 3], g: 0.0003253458453410452, f: 0.013343615181299914
# Path: [0, 2, 1, 1, 3], g: 0.00023538405133909478, f: 0.013253653387297963
# Path: [0, 2, 1, 2, 3], g: 0.00012593585534416657, f: 0.013144205191303035
# Path: [0, 3, 1, 4], g: 0.0059199016229975225, f: 0.009895783924889025
# Path: [0, 3, 1, 4, 1], g: 0.0010305230281749834, f: 0.31992139486372256
# Path: [0, 3, 1, 4, 4], g: 0.0014277332207865878, f: 0.12626460497811542
# Path: [0, 3, 1, 4, 2], g: 0.0009146386503494914, f: 0.04729173444405475
# Path: [0, 3, 1, 4, 3], g: 0.0018079847239603154, f: 0.014826254059919185
# Path: [0, 1, 2, 4], g: 0.004822844448231185, f: 0.00879872675012269
# Path: [0, 1, 2, 4, 1], g: 0.0008395498070272895, f: 0.31973042164257487
# Path: [0, 1, 2, 4, 4], g: 0.0011631502811932295, f: 0.12600002203852206
# Path: [0, 1, 2, 4, 2], g: 0.0007451407502853287, f: 0.04712223654399059
# Path: [0, 1, 2, 4, 3], g: 0.001472934795835956, f: 0.014491204131794826
# Path: [0, 2, 1, 4], g: 0.002267136433613294, f: 0.006243018735504797
# Path: [0, 2, 1, 4, 1], g: 0.0003946579608311139, f: 0.3192855297963787
# Path: [0, 2, 1, 4, 4], g: 0.0005467769919943957, f: 0.12538364874932323
# Path: [0, 2, 1, 4, 2], g: 0.0003502778829537807, f: 0.046727373676659044
# Path: [0, 2, 1, 4, 3], g: 0.0006924013776146531, f: 0.013710670713573523
# Path: [0, 2, 2, 4, 1, -1], g: 0.0013628499234583315, f: 0.0013628499234583315
# Best Sentence: <sos> grass grass airport green <eos>
# Best Score: 0.0013628499234583315
